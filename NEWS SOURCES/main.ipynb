# %%
import pandas as pd
import numpy as np

raw_data = pd.read_csv("data/2023.csv")

# %%
raw_data
# Out:
#       year company_ric                                       storyId  \
# 0     2023     POOL.OQ  urn:newsml:reuters.com:20231220:nFWN3DF0WC:1
# 1     2023     POOL.OQ  urn:newsml:reuters.com:20231208:nFWN3D32EF:1
# 2     2023     POOL.OQ  urn:newsml:reuters.com:20231208:nFWN3D327F:1
# 3     2023     CHRW.OQ  urn:newsml:reuters.com:20231229:nFWN3DO07V:1
# 4     2023     CHRW.OQ  urn:newsml:reuters.com:20231229:nFWN3DO07V:3
# ...    ...         ...                                           ...
# 5250  2023      ADI.OQ  urn:newsml:reuters.com:20231121:nPlx4YWqqM:5
# 5251  2023      ADI.OQ  urn:newsml:reuters.com:20231121:nPlx4YWqqM:4
# 5252  2023      ADI.OQ  urn:newsml:reuters.com:20231121:nPlx4YWqqM:3
# 5253  2023      ADI.OQ  urn:newsml:reuters.com:20231121:nPlx4YWqqM:2
# 5254  2023      ADI.OQ  urn:newsml:reuters.com:20231121:nPlx4YWqqM:1
#
#                versionCreated  \
# 0     2023-12-20 12:55:28.618
# 1     2023-12-08 14:13:14.145
# 2     2023-12-08 14:13:12.833
# 3     2023-12-29 22:01:31.000
# 4     2023-12-29 21:46:23.152
# ...                       ...
# 5250  2023-11-21 12:00:08.350
# 5251  2023-11-21 12:00:07.520
# 5252  2023-11-21 12:00:07.486
# 5253  2023-11-21 12:00:07.455
# 5254  2023-11-21 12:00:07.426
#
#                                                headline  \
# 0     POOL CORP <POOL.O>: STIFEL RAISES TARGET PRICE...
# 1     POOL CORP <POOL.O>: DEUTSCHE BANK CUTS TARGET ...
# 2     POOL CORP <POOL.O>: DEUTSCHE BANK CUTS TO HOLD...
# 3     BRIEF-CH Robinson Worldwide Entered Into Lette...
# 4     CH ROBINSON WORLDWIDE INC -  ANCORA AGREED TO ...
# ...                                                 ...
# 5250  ANALOG DEVICES Q4 ADJUSTED OPERATING INCOME US...
# 5251                        ANALOG DEVICES Q4 EPS USD 1
# 5252  ANALOG DEVICES Q4 ADJUSTED OPERATING MARGIN 44.7%
# 5253  ANALOG DEVICES Q4 REVENUE USD 2,716 MILLION VS...
# 5254  ANALOG DEVICES Q4 ADJUSTED EPS USD 2.01 VS. IB...
#
#                                                newsText
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Dec 29 (Reuters) - CH Robinson Worldwide Inc <...
# 4     Dec 29 (Reuters) - CH Robinson Worldwide Inc <...
# ...                                                 ...
# 5250  BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5251  BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5252  BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5253  BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5254  BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
#
# [5255 rows x 6 columns]

# %%
data = raw_data.dropna(subset=["newsText"])

data["newsText"]
# Out:
# 3       Dec 29 (Reuters) - CH Robinson Worldwide Inc <...
# 4       Dec 29 (Reuters) - CH Robinson Worldwide Inc <...
# 5       Dec 29 (Reuters) - CH Robinson Worldwide Inc <...
# 6       Dec 29 (Reuters) - CH Robinson Worldwide Inc <...
# 7       (Adds Klaveness Combination Carriers, updates ...
#                               ...
# 5250    BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5251    BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5252    BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5253    BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# 5254    BRIEF-Analog Devices Q4 Adjusted EPS USD 2.01 ...
# Name: newsText, Length: 3371, dtype: object

# %%
for news in data["newsText"].sample(10):
    print("\n\n===")
    print(news)
# Out:
# ===
# By Stephen Nellis
#        Dec 7 (Reuters) - In the first nine months of 2023, U.S.
# data breaches increased by 20% compared to the full year 2022,
# according to a new study that was commissioned by Apple
# <AAPL.O>.
#     The iPhone maker paid for the study, which was conducted by
# Massachusetts Institute of Technology Professor Stuart E.
# Madnick, about a year after it rolled out a new feature to
# expand end-to-end encryption for data stored in its iCloud
# service. The study, which does not include any findings of data
# breaches at Apple itself, argues that breaches are becoming so
# commonplace that the only feasible way to protect consumer data
# is wider use of end-to-end encryption.
#     Such encryption makes it impossible for the company that
# stores the data - or anyone who might hack its servers - to
# unscramble a user's data without also possessing additional
# information, such as the passcode for one of the user's personal
# devices. But that encryption approach also makes it impossible
# for law enforcement officials to access the data without the
# user's knowledge and has long been a friction point between
# technologists and government officials.
#     Britain is considering a law that would mandate access to
# private messages and has encouraged companies such as Meta
# Platforms <META.O> not to expand their use of end-to-end
# encryption.
#     The Apple-backed study, however, found that technology
# companies are frequently attacked by hackers because they
# provide services to valuable targets. Microsoft <MSFT.O>, for
# example, was hit by Chinese hackers this year, who managed to
# steal tens of thousands of U.S. State Department emails.
#     The study said that 98% of organizations have a relationship
# with at least one technology vendor that experienced a data
# breach in the previous two years.
#     "In today’s interconnected world, virtually every
# organization relies on a wide range of vendors and software. As
# a result, hackers only need to exploit vulnerabilities in
# third-party software or a vendor’s system to gain access to the
# data stored by every organization that relies on that vendor,"
# the study said.
#
#  (Reporting by Stephen Nellis in San Francisco; Editing by Chizu
# Nomiyama)
#  ((Stephen.Nellis@thomsonreuters.com;))
#
#
# ===
# Dec 22 (Reuters) - United Airlines Holdings Inc <UAL.O>:
#     * UNITED AIRLINES HOLDINGS -  ON DEC 21, GREG HART, EXEC
# VICE
# PRESIDENT, SPECIAL ADVISOR OF UNITED AIRLINES, INC INFORMED OF
# INTENTION TO RETIRE IN 2024
#
# Further company coverage: [UAL.O]
#
#  ((Reuters.Briefs@thomsonreuters.com;))
#
#
# ===
# Click the following link to watch video: https://share.newscasts.refinitiv.com/link?entryId=1_shzpndmg&referenceId=1_shzpndmg&pageId=Newscasts
# Source: 'Reuters - Business videos'
#
# Description: The United States is among at least 60 countries backing a pledge
# on Tuesday to cut cooling-related emissions by 2050, U.S. State Department
# officials said at the U.N. climate summit in Dubai.
# Short Link: https://refini.tv/3NcwmpE
#
# Video Transcript:
#
# Verified transcript not available
#
#
# ===
# WASHINGTON, Dec 20 (Reuters) - Boeing <BA.N> has won a
# key clearance from China's aviation regulator, the Civil
# Aviation Administration of China, on the deliveries of the 737
# Max aircraft to China, trade publication The Air Current said on
# Wednesday.
#
#  (Reporting by Kanishka Singh and Costas Pitas; Editing by
# Sandra Maler)
#  ((Kanishka.Singh@thomsonreuters.com; +12024508248;))
#
#
# ===
# Dec 7 (Reuters) - Analog Devices Inc <ADI.O>:
#     * ANALOG DEVICES APPOINTS PETER HENRY TO ITS BOARD OF
# DIRECTORS
#     * ANALOG DEVICES INC -  PETER HENRY'S APPOINTMENT EXPANDS
# ADI'S
# BOARD TO 13 MEMBERS
#
# Source text for Eikon: [ID:nBw4bd14za]
# Further company coverage: [ADI.O]
#
#  ((Reuters.Briefs@thomsonreuters.com;))
#
#
# ===
# Dec 29 (Reuters) - CH Robinson Worldwide Inc <CHRW.O>:
#     * CH ROBINSON WORLDWIDE INC - ON DEC 29, ENTERED INTO LETTER
# AGREEMENT WITH ANCORA CATALYST INSTITUTIONAL, LP AND ITS
# AFFILIATES PARTY THERETO
#     * CH ROBINSON WORLDWIDE - BOARD ACKNOWLEDGED IT WILL
# RENOMINATE
# CURRENT DIRECTORS HENRY W. "JAY" WINSHIP AND HENRY J. MAIER FOR
# ELECTION AT 2024 MEETING
#     * CH ROBINSON WORLDWIDE INC -  ANCORA AGREED TO BOARD'S
# RENOMINATION PROVIDED CO RENOMINATES MESSRS
#
# Further company coverage: [CHRW.O]
#
#  ((Reuters.Briefs@thomsonreuters.com;))
#
#
# ===
# ** Shares of biotech co Fusion Pharmaceuticals <FUSN.O> rise
# 11.2% to $8.86 after Raymond James upgrades stock to "strong
# buy" from "outperform"
#     ** Stock hit its highest level in over two years earlier in
# today's session
#     ** Brokerage says upgrade follows a series of high-profile
# M&A activity among radiopharma cos including Bristol-Myers'
# <BMY.N> takeover of RayzeBio <RYZB.O> for about $4.1 bln and Eli
# Lilly's <LLY.N> $1.4 bln takeover of Point BioPharma <PNT.O>
#     ** Expects any potential bid for FUSN would come at a
# significant premium
#     ** Raises PT on stock to $15 from $12, an upside of 88% to
# co's last close, second highest among Wall Street analysts
# covering the stock
#     ** All 14 analysts covering stock rate it "buy" or higher;
# median PT at $12.50 - LSEG data
#     ** FUSN stock has risen over 60% so far this year
#
#
#  (Reporting by Purvi Agarwal in Bengaluru)
#  ((Purvi.Agarwal@thomsonreuters.com))
#
#
# ===
# *
#       Boeing cuts strategy teams in divisions by at least 50%
# -sources
#
#
#         *
#       Cuts go further and faster than first expected -sources
#
#
#         *
#       Boeing says putting strategy teams closer to business
#
#
#         *
#       Boeing declines to comment on the number of jobs affected
#
#
#
#     By Valerie Insinna and Tim Hepher
#        Dec 12 (Reuters) - Boeing Co <BA.N> has embarked on
# deeper-than-expected cuts in its strategy ranks, halving the
# number of planners working within key divisions as it refocuses
# energies on tackling industrial pressures, people familiar with
# the matter said.
#     The move is the latest evidence of renewed industrial
# priorities after Boeing on Monday named Stephanie Pope to the
# new role of chief operating officer, putting the 51-year-old
# Global Services head in line to succeed Dave Calhoun as CEO.
#     Boeing has been grappling with supply disruption at a time
# when it is saddled with almost $40 billion of debt stemming from
# the COVID-19 travel slump and an earlier 737 MAX safety crisis.
#     But some critics worry the increased operational focus is
# diverting attention from Boeing's long-term future at a crucial
# stage for the industry, with redundancy notices due to go out to
# affected strategists this week, according to the sources.
#     In November, Boeing said Marc Allen, who had once been seen
# as a future CEO, would step down as chief strategy officer with
# part of his planning team redeployed to divisions.
#     In a Nov. 16 memo, Calhoun said this involved "enabling and
# empowering our business units," with strategists "directly
# joining the business units they support."
#     However, sources said those units were facing cuts of at
# least 50% in the number of strategists who work day to day
# inside Boeing Global Services and Stan Deal's Boeing Commercial
# Airplanes. The total number of employees affected was unknown.
#     In a sign of the speed of the shake-up, some strategists are
# being told not to go back to work when the 60-day notices land,
# though they will receive job search advice, the sources said.
#     At Defense, plans are evolving more slowly as it first
# combines the division's strategy and business development, but
# cuts of 50% or more are also expected there, the sources said.
#     Boeing confirmed the internal Defense combination but
# declined to comment on the number of job cuts across the
# company. Sources say it has some 200 strategists in total.
#     "We are directly aligning our strategy teams to the business
# units they support," a spokesperson said, adding this was part
# of broader steps taken over several years to simplify corporate
# structure and focus resources on the business.
#     Boeing shares rose 1.4% on Monday.
#
#     FUTURE TECHNOLOGIES
#     Strategy is a perennial chess game in aerospace due to the
# company-sized bets and time needed to master new technology.
#     The decision to cut core strategy teams has already drawn
# criticism from analyst and long-time Boeing skeptic Richard
# Aboulafia. On Monday, he said this and Pope's appointment favor
# the harvesting of past investments over future technologies.
#     "If it doesn't have these things, how does it know where it
# wants to be in five or 10 years?" he said.
#     Not everyone was as pessimistic. One source familiar with
# the company said its divisions had long seen the strategy
# department as a costly rival and predicted it would gradually
# reshape itself.
#     Jefferies analyst Sheila Kahyaoglu on Monday welcomed the
# greater operational focus visible in Pope's appointment.
#     The shake-up comes as the industry studies its crystal ball
# on the future of single-aisle jets, the aerospace cash cow,
# marking one of the biggest strategic choices for a generation.
#     Although successor models are over a decade away, Europe's
# Airbus <AIR.PA> has already aired a key component of its
# potential strategy by suggesting it may request public support:
# a mechanism that helped trigger a 17-year trade war with Boeing.
#     Calhoun has tempered expectations of a new Boeing airplane
# until the mid-2030s, saying it must be 20%-30% more efficient.
# Shares are up 30% this year as Boeing conserves resources in
# favor of paying off $39 billion in debt.
#     Even so, sources say it never fully halted work on a 737
# replacement. But Boeing's storied Product Strategy team will now
# sit under Product Development, which runs existing projects,
# Boeing confirmed in response to a Reuters query.
#     "One hopes the strategy changes are not about abandoning the
# future of the company in terms of the need to develop new
# programs (and) respond to the changing environment, particularly
# decarbonization," said Agency Partners analyst Nick Cunningham.
# "On the other hand, you could argue that it's just realistic."
#
#  (Reporting by Tim Hepher in Paris and Valerie Insinna in
# Washington; Editing by David Gaffen and Christopher Cushing)
#  ((tim.hepher@thomsonreuters.com; +33 1 49 49 54 52; Reuters
# Messaging: tim.hepher.thomsonreuters@reuters.net))
#
#
# ===
# Click the following link to watch video: https://share.newscasts.refinitiv.com/link?entryId=1_olt0yp15&referenceId=1_olt0yp15&pageId=Newscasts
# Source: 'Reuters - Business videos'
#
# Description: Trading was muted in the shortened holiday week, but the S&P 500
# is hovering around its all-time high seen in March 2022.
# Short Link: https://refini.tv/3vjaS4A
#
# Video Transcript:
#
# Verified transcript not available
#
#
# ===
# Dec 12 (Reuters) - Take-Two Interactive Software Inc
# <TTWO.O>:
#     * ZYNGA: COLLABORATION WITH WARNER BROS. PICTURES TO FEATURE
# WONKA
# IN MULTIPLE ZYNGA GAMES
#
# Source text for Eikon: [ID:nBw2JhGfJa]
# Further company coverage: [TTWO.O]
#
#  ((Reuters.Briefs@thomsonreuters.com;))

# %%
text_lengths = data["newsText"].str.len()
text_lengths.describe()
# Out:
# count     3371.000000
# mean      2263.953723
# std       3754.952796
# min         69.000000
# 25%        482.000000
# 50%        950.000000
# 75%       2629.000000
# max      32542.000000
# Name: newsText, dtype: float64

# %%
text_lengths.hist(bins=100)
# Out:
# <Axes: >

# %%
text_lengths[text_lengths < 4000].hist(bins=100)
# Out:
# <Axes: >

# %%
np.log10(text_lengths).hist(bins=50)
# Out:
# <Axes: >
